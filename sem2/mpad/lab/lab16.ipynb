# %% [markdown]
# # Story
#
# > Mr. Holmes is working in his office when he receives a phone call from his neighbour Dr. Watson, who tells him that Holmes' burglar alarm has gone off. Convinced that a burglar has broken into his house, Holmes rushes to his car and heads for home. On his way, he listens to the radio, and in the news, it is reported that there has been a small earthquake in the area. Knowing that earthquakes have a tendency to make burglar alarms go off, he returns to his work.
# >
# > *(Burglary or Earthquake, Pearl 1988)*

# %%
from IPython.display import Image
Image(filename='./lab16/lab16.png', width=400)

# %% [markdown]
# Serial connections: 𝐵 → 𝐴 → 𝑊, 𝐸 → 𝐴 → 𝑊
#
# Diverging connection: 𝐴 ← 𝐸 → 𝑅
#
# Converging connection: 𝐵 → 𝐴 ← 𝐸

# %% [markdown]
# **For the past 2 years, there were 50 house robberies in the neighbourhood. It consists of 1350 houses.**
#
# House per hear is $25/1350 = 0.00005$
#
# $P(B = true) = 0.00005$
#
# $P(B = false) = 0.99995$

# %% [markdown]
# **Expect 3 earthquakes each year.**
#
# $3/365 = 0.0082$
#
# $P(E = true) = 0.0082$
#
# $P(E = false) = 0.9918$

# %% [markdown]
# **The monitoring company claims the alarm catches 95% of burglaries.**
#
# $P(A = true | B = true, E = false) = 0.95$
#
# $P(A = false | B = true, E = false) = 0.05$
#
# **Someone living in the same neighbourhood said that this type of alarm is triggered by 1 out of 5 earthquakes.**
#
# $P(A = true | B = false, E = true) = 0.2$
#
# $P(A = false | B = false, E = true) = 0.8$
#
#
# If both alarm, end earthquake are true, let's assume bigger probability than with the single event.
#
# $P(A = true | B = true, E = true) = 0.98$
#
# $P(A = false | B = true, E = true) = 0.02$
#
#
# For false alarms let's use low value.
#
# $P(A = true | B = false, E = false) = 0.001$
#
# $P(A = false | B = false, E = false) = 0.999$

# %% [markdown]
# **Watson is somewhat deaf, but he is definitely not a prankster.**
#
# Means that if the alarm rings the probability would not be zero as he will eventually come close to the sound and hear it.
#
# $P(W = true | A = true) = 0.75$
#
# $P(W = false | A = true) = 0.25$
#
# If the alarm is off, he will not prank call to say it "is on".
#
# $P(W = true | A = false) = 0$
#
# $P(W = false | A = false) = 1$

# %% [markdown]
# **Local radio station is not very reliable, it will sometime report earthquake even if it occurred in another state. On the other hand, they never failed to inform about an earthquake if it occurred in the neighbourhood.**
#
# **On the other hand, they never failed to inform about an earthquake if it occurred in the neighbourhood.**
#
# $P(R = true | E = true) = 1$
#
# $P(R = false | E = true) = 0$
#
# **Local radio station is not very reliable, it will sometime report earthquake even if it occurred in another state.**
#
# $P(R = true | E = false) = 0.2$
#
# $P(R = false | E = false) = 0.8$

# %%
Image(filename='./lab16/watson.png', width=400)

# %% [markdown]
# After updating beliefs, we can see that the probability of Watson calling given the evidence is quite low - 0.002.
